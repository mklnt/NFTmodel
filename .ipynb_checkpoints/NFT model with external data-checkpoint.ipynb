# %%
from pylab import *
# %matplotlib inline
m=0.00086
Y=7. # number of years
dY=12 # intervals of years (supposing equal onboarding probability throughout the year)
S=int(Y*dY) # number of steps
Years=[0]*S
for t in range(0,S):
    Years[t]=t/dY #+2022
ly=range(0,int(Y+1)) #Years shown
Onboardings=[]*S
OFCvalue=[]*S
OFCcirculation=[5000000,5000000,5000000,5000000,11525000,18050000,24575000,31100000,34025000,36950000,39875000,42800000,44600000,46400000,48200000,50000000,50000000,50000000,50000000,50000000,50000000,50000000,55555548,61111096,66666644,72222192,77777740,83333288,91388835,99444382,107499929,115555476,123611023,131666570,136388785,141111184,145833583,150555982,155278381,160000780,162223180,164445580,166667980,168890380,171112780,173335180,175557580,177779980,180002380,182224780,184447180,186669580,188891980,191114380,193336780,195559180,197781580,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796,200003796] #,200003796,200003796]
#print(len(OFCcirculation))
OnboardingsPerYear=[0,20,55,79,124,160,183,225]
for y in range(1, len(OnboardingsPerYear)):
    p=np.linspace(OnboardingsPerYear[y-1],OnboardingsPerYear[y]-1,dY)
    #    OFCrequest.append(p)
    for i in range(0, len(p)):
        Onboardings.append(p[i])
#print(Onboardings)

for l in range(0,S):
    OFCvalue.append(m*l*l+0.18)



fig, ax1 = plt.subplots(figsize=(20,12)) 

ax1.plot(Years, OFCvalue, label='OFC value', color='red',linewidth=2)
grid(color='grey', linestyle='-', linewidth=0.2)
rc('font', size=12)
ax1.set_xlabel("Years",fontsize=18)
ax1.set_ylabel("€ per token",fontsize=18)
legend(loc='lower right',frameon=True,fontsize=20)
ax2 = ax1.twinx() 
ax2.plot(Years, Onboardings, label='demand', color='black',linewidth=2)
ax2.set_ylabel('Onboardings', color = 'black') 
YearsShown=ly
xticks(YearsShown)
legend(frameon=True,fontsize=20)
tight_layout()

# %%
Y=7. # number of years
dY=12. # intervals of years (supposing equal onboarding probability throughout the year)
S=int(Y*dY) # number of steps
Years=[0]*S
for t in range(0,S):
    Years[t]=t/dY #+2022
value=[0]*S
